# %%
import requests
from bs4 import BeautifulSoup

# my_url = input("Url to scrape:")
my_url = "https://www.newegg.com/p/pl?d=playstation"
print("Grabbing...", my_url)

response = requests.get(my_url)
print("Status is",response.status_code)

if response.status_code != 200:
    print(f"You can't scrape this. {response.status_code}")
else:
    print(f"scraping...\n{response.text}")
    
    html = response.text
    soup = BeautifulSoup(html, "html.parser")
    

    items_ = soup.find_all("div", attrs={"class":"item-cell"})
    for i in range(len(items_)):
        item = items_[i]
        print(item.text)
# Out:
# Grabbing... https://www.newegg.com/p/pl?d=playstation
# Status is 200
# scraping...
# <!DOCTYPE html><html lang="en-us" class="show-tab-store"><head><title>playstation | Newegg.com</title><meta charSet="utf-8"/><meta http-equiv="content-type" content="text/html; charset=UTF-8"/><meta name="referrer" content="always"/><meta name="keywords" content="playstation"/><meta name="description" content="Search Newegg.com for playstation. Get fast shipping and top-rated customer service."/><meta property="og:image" content="https://c1.neweggimages.com/WebResource/Themes/Nest/logos/logo_newegg_400400.png"/><meta property="og:description" content="Search Newegg.com for playstation. Get fast shipping and top-rated customer service."/><meta property="og:url" content="https://www.newegg.com/p/pl?d=playstation"/><meta property="og:type" content="website"/><meta property="og:title" content="playstation | Newegg.com"/><meta name="language" content="english"/><meta name="copyright" content="© 2000-2024 Newegg Inc."/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="robots" content="index,follow,max-image-preview:large,max-snippet:-1"/><meta name="X-DNS-Prefetch-Control" content="on"/><meta name="format-detection" content="telephone=no"/><link rel="shortcut icon" type="image/x-icon" href="https://c1.neweggimages.com/WebResource/ngm/newegg.ico"/><link rel="canonical" href="https://www.newegg.com/p/pl?d=playstation"/><link rel="amphtml" href="https://www.newegg.com/amp/p/pl?d=playstation"/><link rel="alternate" type="application/rss+xml" title="Newegg Product List" href="https://www.newegg.com/d/Product/RSS?Submit=ENE&amp;IsNodeId=1"/><link rel="preconnect" href="https://c1.neweggimages.com/" crossorigin=""/><link rel="preconnect" href="https://imk.neweggimages.com/" crossorigin=""/><link rel="preconnect" href="https://promotions.newegg.com/" crossorigin=""/><link rel="preload" href="https://c1.neweggimages.com/WebResource/Themes/WWW/fonts/NE-desktop.woff2?cm96ca" as="font" type="font/woff2" crossorigin="anonymous"/><link rel="preload" href="https://c1.neweggimages.com/WebResource/Themes/WWW/fonts/new-desktop.woff2?dw4b5510" as="font" type="font/woff2" crossorigin="anonymous"/><script>(function(){if (navigator.userAgent.match(/Newegg.+App/ig)||navigator.userAgent.match(/bot/ig)) return;var self = document.currentScript; var o = document.createElement('script'); o.src ='https://cmp.osano.com/AzydZ7TEEX0GW2hin/3c115a66-ecfb-4dbf-929a-5d9c71025132/osano.js?v=0.3'; o.async = false; try {self.parentElement.replaceChild(o, self);} catch (error) {console.log(error);}})();</script><style>.osano-cm-dialog--type_bar{display:none;}.osano-cm-widget{display: none;}</style><script>function showOsanoBar(){window.Osano&&Osano.cm.addEventListener('osano-cm-initialized', function(){if (window.Osano.cm.countryCode !='us'){document.querySelector('.osano-cm-dialog--type_bar').setAttribute('style','display:flex;');}});document.querySelector('#otBtnSpan')&&document.querySelector('#otBtnSpan').setAttribute('style','display:inline;');if(document.querySelector('#ot-sdk-btn')){document.querySelector('#ot-sdk-btn').innerText='Cookie Preferences';document.querySelector('#ot-sdk-btn').addEventListener('click',function(){window.Osano&&window.Osano.cm.showDrawer('osano-cm-dom-info-dialog-open');});}}window.addEventListener('DOMContentLoaded',showOsanoBar);</script><script type="text/javascript">!function(){try{if(!navigator.userAgent.match(/Newegg.+App/ig))return;var e=document.createElement("style");e.innerText="html.sticky-header-top body{padding-top: 0px!important;}header{display: none;}footer{display: none;}",document.querySelector("head").append(e)}catch(t){console.log(t)}}();</script><script>window.__PolyfillScripts__={"core-js":"https://c1.neweggimages.com/WebResource/Scripts/WWW/core-js.polyfill.min.js","intersection-observer":"https://c1.neweggimages.com/WebResource/Scripts/WWW/intersection-observer.polyfill.min.js"}</script><script defer="" src="https://c1.neweggimages.com/WebResource/Scripts/WWW/runtime~search~ProductList-bd08e1fc.js"></ ...
# <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch"}]);</script>
#                               <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="RGD28-F75F5-NJQ8B-DAKUQ-TEPC8",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"RGD28-F75F5-NJQ8B-DAKUQ-TEPC8";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="nc3aegaxz4ypoznihpla-f-ec3fa3767-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"36","ak.cp":"589096","ak.ai":parseInt("248389",10),"ak.ol":"0","ak.cr":13,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"64b9b61","ak.r":40959,"ak.a2":n,"ak.m":"","ak.n":"essl","ak.bpcip":"104.182.2.0","ak.cport":59586,"ak.gh":"23.77.200.164","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1705524182","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"166","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head><body><div><script async src="https://c1.neweggimages.com/webresource/Scripts/Others/MarketingChannel/processecmv5.js"></script></div><div><script ...
# <script type="text/javascript">(function(){var darkv = document.cookie.match('(^|;) ?NV_Theme=([^;]*)(;|$)');var dark = darkv ? darkv[2] : "false";if (dark == "true") {if(!document.getElementById('NewTemplate')){jQuery('html').addClass('dark-mode');}else{document.documentElement.classList.add("dark-mode")}}var style = document.createElement("style");var darkCss='#Dark_Mode{display:none;}.header2021-toggle{z-index:5}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:20px}.header2021-toggle:hover{transform:scale(1)}.header2021-toggle:hover .bg-lightgray{background-color:rgba(235,235,235,1)}.header2021-toggle .toggle-body{border:1px solid #212121;border-radius:30px}.header2021-toggle .toggle-body-inner:after{border-radius:30px;width:30px;top:0;bottom:0;margin-left:-1px;box-shadow:0 1px 6px 0 rgb(0 0 0 / 16%)}.header2021-toggle .toggle-handle{font-size:20px;color:#474747}.header2021-toggle .dark-mode-tooltip{padding:5px 15px;white-space:nowrap}.header2021-toggle.menu.at-bottom .menu-body{left:auto;right:0;margin-top:12px;text-align:left}.header2021-toggle.at-bottom>.menu-arrow{left:auto;right:20px;text-align:left}.header2021-toggle.at-bottom>.menu-body>.menu-arrow{left:auto!important;right:20px}.dark-mode .header2021-toggle .toggle-handle.take-on{padding-left:8px}.dark-mode .header2021-toggle:hover .bg-lightgray{background-color:#ea7421}.dark-mode .header2021-toggle .toggle-body{border:1px solid #835b38}.dark-mode .header2021-toggle .bg-lightgray{background-color:#e05d00}.dark-mode .header2021-toggle input[type="checkbox"]:checked ~ .toggle-body .toggle-body-inner:after{margin-right:0;margin-left:0;top:0}.dark-mode .header2021-toggle .toggle-body-inner:after{box-shadow:0 6px 6px 0 rgb(0 0 0 / 16%)}@media(max-width:599px){.header2021-inner{padding:15px 2px}.header2021-logo{width:60px}.header2021-country.header2021-nav:not(:first-child){margin-left:15px}.header2021-toggle .bg-lightgray{background:#fff}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:15px}.header2021-toggle .toggle-body{min-width:30px;height:30px;border-radius:50%}.header2021-toggle .toggle-body-inner{width:100%;height:100%;transform:translateX(0);justify-content:center;align-items:center}.header2021-toggle .toggle-handle{height:100%;line-height:1.1;padding:0;font-size:22px;justify-content:center;z-index:2}.header2021-toggle .toggle-body-inner:after{content:none}.header2021-toggle .toggle-handle.take-off{padding:0}.header2021-toggle .toggle-handle.take-on,.header2021-toggle.menu.at-bottom .menu-body{display:none}.dark-mode .header2021-toggle .toggle-handle.take-on{display:flex;padding:0}.dark-mode .header2021-toggle .toggle-handle.take-off{display:none}.section-right>.line-vertical-new{margin:0 0 0 10px}}@media(max-width:350px){.header2021-nav-inner,.header2021-nav.menu .header2021-nav-inner{padding-left:26px;height:26px;min-height:26px}.header2021-country-flag{width:26px;height:26px}.header2021-nav-icon{width:26px;height:26px;line-height:26px;font-size:24px;top:2px}.header2021-nav ~ .header2021-nav{margin-left:5px}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:10px}.header2021-toggle .toggle-body{min-width:24px;height:24px}.header2021-toggle .toggle-handle{font-size:16px}}';try{style.appendChild(document.createTextNode(darkCss));}catch(ex){style.styleSheet.cssText = darkCss;}var head = document.getElementsByTagName("head")[0];head&&head.appendChild(style);var darkbut = jQuery('<div class="header2021-nav header2021-toggle toggle toggle-m menu at-bottom"><label id="darkLabel"><input type="checkbox" id="checkdarkmode"><span class="toggle-body bg-lightgray font-l"><span class="toggle-body-inner"><span class="toggle-handle take-on">&#9790;</span><span class="toggle-handle take-off ">&#9728;</span></span></span></label><div id="darkModal" class="menu-body bg-white radius-s shadow-level-1"><i class="menu-arrow"></i><p class="dark-mode-tooltip">Switch to Dark Mode</p></div></div>');jQuery(document).ready(function (){jQuery('.head ...
# </div><div><script type="text/javascript">;;; (function () { var ADRPattern = /Newegg.+Android.+App/ig; var IPNPattern = /Newegg.+(iPhone|iPad).+App/ig; var Container = { APP: 'GTM-TF5LHJ5', EGG: 'GTM-WJ2PC5C' }; function LoadContainer(w, d, s, l, i) { w[l] = w[l] || []; w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' }); var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src = 'https://imk.neweggimages.com/webresource/scripts/gatra/lib/usa/neggtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f); }; if (navigator.userAgent.match(ADRPattern) || navigator.userAgent.match(IPNPattern)) {  } else { LoadContainer(window, document, 'script', 'dataLayer', Container.EGG); } })();</script></div><div><script type="text/javascript">;;; (function () { var ADRPattern = /Newegg.+Android.+App/ig; var IPNPattern = /Newegg.+(iPhone|iPad).+App/ig; var Container = { APP: 'GTM-TF5LHJ5', EGG: 'GTM-WJ2PC5C' }; function LoadContainer(w, d, s, l, i) { w[l] = w[l] || []; w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' }); var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src = 'https://imk.neweggimages.com/webresource/scripts/gatra/lib/app/neggtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f); }; if (navigator.userAgent.match(ADRPattern) || navigator.userAgent.match(IPNPattern)) { LoadContainer(window, document, 'script', 'dataLayer', Container.APP); } else { } })();</script></div><div><script type="text/javascript" >;(function () {var s = document.createElement("script");
#   s.defer=true;
#  s.type = "text/javascript";
#    s.src = "//imk.neweggimages.com/webresource/scripts/plugin/inhousebiztra.js";
#  var node = document.getElementsByTagName("script")[0];
#  node.parentNode.insertBefore(s, node);})();</script></div><div><style>@import url(https://c1.neweggimages.com/webresource/themes/WWW/CSS/fixManufactory.css)</style></div><div><style>@media (max-width: 600px) {.recommend-seller {display: none;}}</style><script type="text/javascript" defer>(function() {var isMobile = false; var query = window.location.search.substring(1); var vars = query.split('&'); for (var i = 0; i < vars.length; i++) {var pair = vars[i].split('='); if (pair[0] == 'template') {isMobile = true; break; } } if (isMobile) {return; } if(window.location.href.indexOf('/p/pl') > -1){var urlParams = new URLSearchParams(window.location.search); if(urlParams.has('d')){var d = urlParams.get('d'); var keywords=['gaming pc','pc','prebuilt gaming pc','gaming desktop','desktop computer','prebuilt pc','prebuilt','desktop','best prebuilt gaming pc','pc for gaming','cheap gaming pc','mini gaming pc','laptop', 'laptops', 'MSI laptop', 'Asus laptop', 'intel 11th gen laptop', '12th gen laptop', 'hp laptop', 'lenovo laptop', '13th gen laptop', 'lenovo','Gaming Laptop', 'Gaming laptops', 'laptop gaming', 'laptop gamer', 'GAME LAPTOP', 'laptop rtx', 'rtx laptop', 'gaming laptop deals', 'BEST LAPTOP FOR GAMING', 'MSI gaming laptop', 'msi laptop gaming', 'Rtx 3070 laptop', '3070 laptop', 'Rtx 3080 laptop', '3080 laptop', 'Asus gaming laptop', 'lenovo legion', 'lenovo legion 5', 'lenovo legion 7', 'gigabyte laptop', 'gigabyte laptops', 'rtx 3080ti laptop', '4090 laptop', 'rtx 4090 laptop', '4080 laptop', 'rtx 4080 laptop', 'RTX 4080 LAPTOP', '4080 GAMING LAPTOP', '4070 laptop', 'rtx 4070 laptop', '4070 LAPTOP', '4060 laptop', 'laptop 4060', 'rtx 4060 laptop', '4060 GAMING LAPTOP', '4050 laptop', 'rog strix laptop', 'asus rog laptop', 'ROG laptop', 'gigabyte g5', 'acer nitro', 'BUDGET GAMING LAPTOP', 'CHEAP GAMING LAPTOP', 'AFFORDABLE GAMING LAPTOPS', 'ASUS TUF gaming laptop', 'asus tuf laptop', 'lenovo loq', 'razer blade', 'open box gaming laptop']; if(d && keywords.includes(d.toLowerCase())){return; } } } document.addEventListener('DOMContentLoaded', function() {var mathjsScript = document.createElement('script'); mathjsScript.defer = true; mathjsScript.type = 'text/javascript'; mathjsScript.src = 'https://c1.neweggimages.com/webresource/Scripts/Others/math.min.js'; var node1 = document.getElementsByTagName('script')[0]; node1.parentNode.insertBefore(mathjsScript, node1); var sellerScript = document.createElement('script'); sellerScript.defer = true; sellerScript.type = 'text/javascript'; sellerScript.src = 'https://c1.neweggimages.com/webresource/Scripts/Others/SellerRecommendations/seller-recommendations.10.0.min.js'; var node2 = document.getElementsByTagName('script')[0]; node2.parentNode.insertBefore(sellerScript, node2); }); })(); </script></div><div><script type="text/javascript">(function () {
#     try {
#         jQuery(document).ready(function () {
#             var topScript = document.createElement("script");
#             topScript.type = "text/javascript";
#             topScript.src = "https://c1.neweggimages.com/webresource/Scripts/Others/BestSellerAndL30d/entranceOnPLPWithoutKeywords-v2.js";
#             var node = document.getElementsByTagName('script')[0];
#             node.parentNode.insertBefore(topScript, node);
#         })
#     } catch (e) {}
# })();</script></div><div><script type="text/javascript" defer src='https://c1.neweggimages.com/webresource/Scripts/Others/ShippingEstimate/shippingestimate-v.5.1.min.js'></script></div><div>
#             <script type="text/javascript">
#             ;;;(function() {
#       window.__ga_biItems=[{pages: ["all"],events:["view_item","select_item","view_item_list"],property:["item_range","spa","best_seller","lowest_price","deal_type","boost_type"]}];    window.__ga_forbiddenList = [{
#  pages: ["all"],
#   events:["recommendation_module_click","search_ahead_view","legacy_view","legacy_click","view_item_list","recommendation_module_view","spa_view","spa_click","search_ahead_click","infocard_view","infocard_click","web_notification_view","trending_keywords_view","select_item"],
#   clearGa4: true,
#   clearInhouse:false,
#       }
#    ];
#                 window.__ga_mappingAdobe = [{
#    events:["event63"],
#    eventName:"legacy_click",
#    mapping:{
#   legacy_element_value:"evar78",
#  module_name:"evar79",
#    products:"products"
#     }
#    },{
#    events:["event168"],
#    eventName:"legacy_view",
#    mapping:{
#   legacy_element_value:"evar78",
#    products:"products"
#     }
#    },{
#  events: ["event21"],
#  eventname: "email_subscribed",
#  mapping:{
#  }
#  }, {
#  events: ["event40"],
#  eventname: "modules_click", mapping:{
#  module_name: "eVar103"
#  }
#  }, {
#  events: ["event91"],
#  eventname: "modules_view", mapping:{
#  module_name: "eVar79"
#  }
#  }];
#                 window.__ga_linkInternalFilters = "javascript:,newegg.com,gamecrate.com,abs.com,checkout.us.zip.co,zip.co,checkout.quadpay.com,3debspay.boc.cn,alfabank.ru,arcot.com,billmelater.com,citibank.co.kr,ftpsllc.com,garanti.com.tr,hyundaicard.com,kbcard.com,keb.co.kr,masterpass.com,mycardsecure.com,newegg3.com.sh,paypal.com,samsungcard.co.kr,secure2gw.ro,securecode.com,secureserver.net,securesuite.co.uk,securesuite.net,shinhancard.com,verifiedbyvisa.com,visa.com,visa.com.ar,web.v.me,secondfunnel.com,cardinalcommerce.com,secure.neweggbusiness.com,www-newegg-com.cdn.ampproject.org,www.newegg.ca,secure.newegg.ca,kb.neweggbusiness.com,www.neweggbusiness.com,help.newegg.ca,secure.m.newegg.ca,secure.newegg.com,www.rosewill.com,neweggbusiness.com,sellerportal.newegg.cn,partner.gqc.newegg.space,help.neweggbusiness.com,secure.newegg6.com.sh,sellerportal62780.gqc.newegg.space,central3.newegg.org,partner.newegg.cn,secure.newegg4.com.sh,newegg.io,newegggpu.com,justgpu.com";
#             })()
#         </script>
# </div><div>
#           <script type="text/javascript" >
#           jQuery(document).ready(function(){
#             try {
#               var url = "https://" + window?.location?.hostname + '/tools/nas-builder?cm_sp=tool_entrance-_-PLP_item-_-nas-builder';
#               var subIds =[124]
#               var style = '<style type="text/css">.item-combo p:hover {text-decoration: underline;}.item-combo p .ico-nas {width: 14px;height: 14px;font-size: 14px;background: url("https://c1.neweggimages.com/webresource/themes/Nest/images/icons/icon_nas.svg");background-size: 100% 100%;display: inline-block;margin: 0 4px 0 0;position: relative;top: 2px;}</style>'
#               jQuery('head')?.append(style)
#               jQuery('.list-wrap .item-cells-wrap .item-cell .item-container')?.each(function (index, target) {
#                 const itemNumber = target?.id
#                 const item = __initialState__?.Products?.find(item => item?.ItemCell?.Item == itemNumber)
#                 if(subIds?.includes(item?.ItemCell?.Subcategory?.SubcategoryId)){
#                   const targetDom = jQuery(target)?.find('.item-operate .item-compare-box')
#                   targetDom?.before('<a href='+ url +' target="_blank" class="item-msg link-blue"><div class="item-combo"><p><i class="ico-nas"></i> NAS Builder<i class="fa fa-caret-right"></i></p></div></a>')
#                 }
#               })
#             } catch (error) {
#               console.error(error)
#             }
#           })
#         </script>
# </div><div><script type="text/javascript">!function(){const e=new URLSearchParams(window.location.search),t=e.get("ranMID"),n=e.get("ranSiteID");if(t&&n){const e=new Date,o=e.getUTCFullYear(),r=String(e.getUTCMonth()+1).padStart(2,"0"),i=String(e.getUTCDate()).padStart(2,"0"),s=String(e.getUTCHours()).padStart(2,"0"),d=String(e.getUTCMinutes()).padStart(2,"0"),c=`${o}${r}${i}_${s}${d}`,u=encodeURIComponent("amid:"+t+"|ald:"+c+"|atrv:"+n),l=new Date;l.setDate(l.getDate()+180);const a=l.toUTCString(),p=window.location.hostname.split('.'),h=p.slice(-2).join('.'),m=h.startsWith('localhost')?'localhost':'.'+h;document.cookie="rmStoreGateway="+u+"; expires="+a+"; path=/; domain="+m+"; secure; SameSite=Lax"}}();</script></div><div><script type="text/javascript" defer src='https://c1.neweggimages.com/webresource/Scripts/Others/RequestQuote/requestquote-v3.js'></script></div><div><script type="text/javascript">
#           (function () {
#             function AddGroupBuy(prop) {}
#             AddGroupBuy.prototype = {
#                 constructor: AddGroupBuy,
#                 getGroupBuyItem: function () {
#                     jQuery.ajax({
#                         type: "get",
#                         url: document.location.protocol + "//" + document.location.host + '/api/Common/GBuy?countryCode=USA',
#                         contentType: "application/json",
#                         dateType: "json",
#                         success: function (data) {
#                             this.checkGroupBuyItem(data);
#                         }.bind(this)
#                     })
#                 },
#                 checkGroupBuyItem: function (data) {
#                     //check if have group buy today
#                     var dataJson = JSON.parse(JSON.parse(data));
#                     if (!dataJson || dataJson.length === 0) {
#                         return;
#                     }
#                     var item = dataJson[0].ItemNumber
#                     url = document.location.protocol + "//" + document.location.host + /p/ + item,
#                         that = this;
#                     if (!item) {
#                         return;
#                     }
#                     that.render(url);
#                 },
#                 render: function (url) {
#                     var htmlArr = [];
#                     htmlArr.push('<div class="swiper-slide swiper-slide-active">');
#                     htmlArr.push('  <a class="header2021-portal" href="' + url + '?cm_sp=group-buy-_-top-keywords" title="Group Buy">')
#                     htmlArr.push('      <div class="tag tag-s is-new at-left" style="margin: 0;margin-right: 5px;"><div class="tag-text">NEW</div></div>');
#                     htmlArr.push('      <span class="font-s">Group Buy</span>');
#                     htmlArr.push('  </a>')
#                     htmlArr.push('</div>');
#                     //inject to page header
#                     jQuery('#Portals_swiper .swiper-wrapper').prepend(htmlArr.join(''));
#                 }
#             }
#             jQuery(function() {
#                 try {
#                     var isRender = false
#                     var targetNode = jQuery('.header2021 .header2021-inner:first .section-right').get(0);
#                     var observer = new MutationObserver(function(mutations) {
#                         mutations.forEach(function(mutation) {
#                             if (isRender) return
#                             var parentDom = jQuery(mutation.target).parent()
#                             if (mutation.type === 'attributes' && parentDom.hasClass('header2021-returns')) {
#                                 isRender = true
#                                 new AddGroupBuy({}).getGroupBuyItem()
#                                 observer.disconnect();
#                             }
#                             if (mutation.type === 'childList' && mutation.addedNodes.length > 0) {
#                               for(let node of mutation.addedNodes) {
#                                 if (node.classList && node.classList.contains('header2021-notify')) {
#                                   isRender = true
#                                   new AddGroupBuy({}).getGroupBuyItem()
#                                   observer.disconnect();
#                                 }
#                               }
#                             }
#                         });
#                     });
#                     var config = { childList: true, subtree: true, attributes: true, attributeFilter: ['previewlistener'] };
#                     observer.observe(targetNode, config);
#
#                 } catch (e) {
#                   console.error(e);
#                 }
#
#             });
#         })()
#           </script></div><div><style>.header2021 .page-content-inner{max-width: inherit !important;}</style></div><div><style>#trendingBanner_769220{background-image: linear-gradient(135deg, #050E80 0%, #0049E4 100%);box-shadow: none;background-color: transparent;color: #FFCF1D; transform: skewX(-10deg); border-radius: 4px 0;padding: 0 6px;} .header2021 .header2021-portal > span {line-height: 20px;}</style></div><div><style>@import url(https://c1.neweggimages.com/webresource/themes/www/css/holiday/theme_anniversary.css)</style></div><div id="app"><header class="header2021 bg-white"><div class="page-content-inner"><div class="header2021-inner"><div class="section-left auto-flex"><div><div class="header2021-hamburger-new header2021-hamburger menu at-bottom"><i class="header2021-hamburger-icon ico ico-bars bg-transparent-gray" aria-label="Site Menu"></i></div></div><div class="header2021-logo"><a href="https://www.newegg.com/" class="header2021-logo-img" title="Newegg.com - Computer Parts, Laptops, Electronics, HDTVs, Digital Cameras and More!"><img src="https://c1.neweggimages.com/WebResource/Themes/Nest/logos/Newegg_full_color_logo_RGB.SVG" width="297" height="150" alt="Newegg"/></a></div><div class="header2021-nav header2021-location  menu at-bottom"><a href="#" class="header2021-nav-inner bg-transparent-gray" title="Select address "><i class="ico ico-map-marker header2021-nav-icon" aria-label="icon of my location"></i><div class="header2021-nav-title text-gray font-s">Hello<!-- --> <span class="header2021-info-nowrap header2021-info-min"></span></div><div class="header2021-nav-subtitle"><span class="">Select address</span> <span></span></div></a></div><div class="header2021-search auto-flex"><div class="header2021-search-inner"><div class="header2021-search-box auto-flex"><input type="search" title="Search Site" autoComplete="off" value="playstation"/><i class="header2021-search-clear ico ico-times"><span class="display-none">clear keywords</span></i></div><div class="header2021-search-button"><button class="ico ico-search" aria-label="Search"><span class="display-none">Search</span></button></div></div></div></div><div class="section-right"><div class="header2021-nav  header2021-country menu at-bottom"><a title="Change Country" class="header2021-country-flag bg-transparent-gray"><i class="flag us"></i><span class="display-none">Change Country</span></a></div><div class="nav-complex"><a href="https://secure.newegg.com/login/signin?nextpage=" class="header2021-nav-inner bg-transparent-gray" title="My Account"><i class="ico ico-user header2021-nav-icon" aria-label="icon of my account"></i></a></div><div class="header2021-nav header2021-returns s-hide"><a href="https://secure.newegg.com/orders/list" class="header2021-nav-inner bg-transparent-gray" title="Orders"><div class="header2021-nav-title text-gray font-s"><span>Returns</span></div><div class="header2021-nav-subtitle">&amp; Orders</div></a></div><div class="header2021-nav header2021-cart"><a href="https://secure.newegg.com/shop/cart" class="header2021-nav-inner bg-transparent-gray" title="Shopping Cart" aria-label="Shopping Cart"><i class="ico ico-shopping-cart header2021-nav-icon" aria-label="icon of shopping cart"></i></a></div></div></div><div class="header2021-inner"><div class="section-left auto-flex"><div id="Portals_swiper" class="header2021-portals"><div class="swiper-container swiper-container-horizontal"><div class="swiper-wrapper"><div class="swiper-slide"></div><div class="swiper-slide"><a class="header2021-portal" id="trendingBanner_769793" href="//www.newegg.com/p/pl?d=PPSSKINVWKVEPJ&DEPA=0&Order=BESTMATCH&cm_sp=Head_Navigation-_-Under_Search_Bar-_-RTX+40+Super+Series&icid=769793" title="RTX 40 Super Series" "><span class="font-s">RTX 40 Super Series</span></a></div><div class="swiper-slide"><a class="header2021-portal" id="trendingBanner_720202" href="//www.newegg.com/Shell-Shocker/EventSaleStore/ID-10381?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Today%27s+ ...
# Your use of this PlayStationStore card ("Card") constitutes your acceptance of these terms and any additional terms available at playstationnetwork.com/ terms-of-service. Activated Cards can only be redeemed through an SEN master account subject to prior acceptance of the SEN Terms of Service and User Agreement and applicable Privacy Policy available at playstationnetwork.caREDEMPTION INSTRUCTIONS:
# 1. Sign into PSN or create an account at playstation.com.
# 2. Go to ‘Redeem Codes’ on PS Store and enter the 12-digit voucher code (Code).
# 3. To purchase PS Plus using the funds from this Code, select the subscription plan of your choice, and complete the Purchase*.
# *Credit/debit card may be required to purchase PS Plus 1 month subscription.om/terms-of-service. PS4, PS3, PS Vita and PSP systems, personal computers, access to the internet, com...</li><li><strong>Model #: </strong>PS10000</li><li><strong>Item #: </strong>N82E16832886063</li><li><strong>Return Policy: </strong><a href="https://kb.newegg.com/Article/Index/12/3?id=1167#95" target="_blank" title="Digital Products Return Policy(New Window)">Digital Products Return Policy</a></li></ul></div><div class="item-action"><ul class="price"><li class="price-was"></li><li class="price-map"> </li><li class="price-current"><span class="price-current-label"></span>$<strong>100</strong><sup>.00</sup> <span class="price-current-range"><abbr title="to">–</abbr></span></li><li class="price-save "></li></ul><p class="item-msg"><a href="https://kb.newegg.com/knowledge-base/shipped-by-newegg/" class="shipped-by-newegg">Shipped by Newegg</a></p><div class="item-operate"><div class="item-button-area"><button class="btn btn-primary btn-mini" title="Add PlayStation Store $100 Gift Card (Email Delivery) to cart">Add to cart <i class="fas fa-caret-right"></i></button></div><div class="item-compare-box"><label class="form-checkbox"><input type="checkbox" autoComplete="off"/><span class="form-checkbox-title">Compare</span></label></div></div></div><div class="item-stock" id="stock_32-886-063"></div></div></div><div class="item-cell" id="item_cell_9SIAWVGK2E5662_2_1"><noscript><p>Starts introducing a sponsored item.</p></noscript><div id="9SIAWVGK2E5662" class="item-container"><a href="https://www.newegg.com/p/3EC-0005-00095?Item=9SIAWVGK2E5662&amp;cm_sp=SP-_-2225290-_-0-_-2-_-9SIAWVGK2E5662-_-playstation-_-playstation-_-2" class="item-img" rel="nofollow"><img src="https://c1.neweggimages.com/ProductImageCompressAll300/AWVGS23102508AMJL09.jpg" title="Playstation 5 Disc Console - Marvel&#x27;s Spider-Man 2 Bundle" alt="Playstation 5 Disc Console - Marvel&#x27;s Spider-Man 2 Bundle" fetchpriority="high"/><div class="btn btn-large btn-quickview">Quick View</div><div class="item-quick-action-container"><button class="quick-action"><i class="fa fa-heart-outline"></i></button></div></a><div class="item-negspa-box"><div class="menu-box item-negspa"><span><i class="fas fa-info-circle-light"></i> Sponsored</span><div class="menu-box-menu" style="display:none"><div class="menu-box-menu-arrow"></div><div class="article"><p>You’re seeing this ad based on the product’s relevance to your search query. If you are a seller and want to participate in this program click here to <a href='https://www.newegg.com/sellers/index.php/marketing-sponsored-product-ads/' class='link-blue'>learn more</a>.</p></div></div></div></div><div class="item-info"><div class="item-branding has-brand-store"></div><a href="https://www.newegg.com/p/3EC-0005-00095?Item=9SIAWVGK2E5662&amp;cm_sp=SP-_-2225290-_-0-_-2-_-9SIAWVGK2E5662-_-playstation-_-playstation-_-2" class="item-title" title="View Details" rel="nofollow"><span class="item-open-box-italic"></span>Playstation 5 Disc Console - Marvel&#x27;s Spider-Man 2 Bundle</a><ul class="item-features"><li><strong>Edition:</strong> Standard Edition</li><li><strong>Processor Type:</strong> AMD Zen 2-based CPU with 8 cores at 3.5GHz</li><li><strong>Installed RAM:</strong> 16GB GDDR6</li><li><strong>Storage Capacity:</strong> Custom 825GB SSD</li><li><strong>Model #: </strong>Marvel&#x27;s Spider-Man 2 Bundle</li><li><strong>Item #: </strong>9SIAWVGK2E5662</li><li><strong>Return Policy: </strong><a href="https://www.newegg.com/Seller-Store/LittleOX?initialTab=returnPolicy" target="_blank" title="View Return Policy(new window)">View Return Policy</a></li></ul></div><div class="item-action"><ul class="price"><li class="price-was"></li><li class="price-map"> </li><li class="price-current"><span class="price-current-label"></span>$<strong>599</strong><sup>.99</sup> <span class="price-current-range"><abbr title="to">–</abbr></span></li><li class="price-save "></ ...
# 1. Sign into PSN or create an account at playstation.com.
# 2. Go to ‘Redeem Codes’ on PS Store and enter the 12-digit voucher code (Code).
# 3. To purchase PS Plus using the funds from this Code, select the subscription plan of your choice, and complete the Purchase*.
# *Credit/debit card may be required to purchase PS Plus 1 month subscription.</li><li><strong>Specifications:</strong> REDEMPTION INSTRUCTIONS:
# 1. Sign into PSN or create an account at playstation.com.
# 2. Go to ‘Redeem Codes’ on PS Store and enter the 12-digit voucher code (Code).
# 3. To purchase PS Plus using the funds from this Code, select the subscription plan of your choice, and complete the Purchase*.
# *Credit/debit card may be required to purchase PS Plus 1 month subscription.</li><li><strong>Model #: </strong>SPS-5000</li><li><strong>Item #: </strong>N82E16832886003</li><li><strong>Return Policy: </strong><a href="https://kb.newegg.com/Article/Index/12/3?id=1167#95" target="_blank" title="Digital Products Return Policy(New Window)">Digital Products Return Policy</a></li></ul></div><div class="item-action"><ul class="price"><li class="price-was"></li><li class="price-map"> </li><li class="price-current"><span class="price-current-label"></span>$<strong>50</strong><sup>.00</sup> <span class="price-current-range"><abbr title="to">–</abbr></span></li><li class="price-save "></li></ul><p class="item-msg"><a href="https://kb.newegg.com/knowledge-base/shipped-by-newegg/" class="shipped-by-newegg">Shipped by Newegg</a></p><div class="item-operate"><div class="item-button-area"><button class="btn btn-primary btn-mini" title="Add PlayStation Store $50 Gift Card (Email Delivery) to cart">Add to cart <i class="fas fa-caret-right"></i></button></div><div class="item-compare-box"><label class="form-checkbox"><input type="checkbox" autoComplete="off"/><span class="form-checkbox-title">Compare</span></label></div></div></div><div class="item-stock" id="stock_32-886-003"></div></div></div><div class="item-cell" id="item_cell_32-886-001_6_0"><div id="32-886-001" class="item-container"><a href="https://www.newegg.com/sony-10-00/p/N82E16832886001" class="item-img"><img src="https://c1.neweggimages.com/ProductImageCompressAll300/32-886-001-04.png" title="PlayStation Store $10 Gift Card (Email Delivery)" alt="PlayStation Store $10 Gift Card (Email Delivery)"/><div class="btn btn-large btn-quickview">Quick View</div><div class="item-quick-action-container"><button class="quick-action"><i class="fa fa-heart-outline"></i></button></div></a><div class="item-info"><div class="item-branding has-brand-store"><a href="https://www.newegg.com/sony-10-00/p/N82E16832886001#IsFeedbackTab" class="item-rating" title="Rating + 4.6"><i class="rating rating-4-5" aria-label="rated 4.6 out of 5"></i><span class="item-rating-num">(162)</span></a></div><a href="https://www.newegg.com/sony-10-00/p/N82E16832886001" class="item-title" title="View Details"><span class="item-open-box-italic"></span>PlayStation Store $10 Gift Card (Email Delivery)</a><ul class="item-features"><li><strong>Disclaimer:</strong> N82E16832886001</li><li><strong>Model #: </strong>SPS-1000</li><li><strong>Item #: </strong>N82E16832886001</li><li><strong>Return Policy: </strong><a href="https://kb.newegg.com/Article/Index/12/3?id=1167#95" target="_blank" title="Digital Products Return Policy(New Window)">Digital Products Return Policy</a></li></ul></div><div class="item-action"><ul class="price"><li class="price-was"></li><li class="price-map"> </li><li class="price-current"><span class="price-current-label"></span>$<strong>10</strong><sup>.00</sup> <span class="price-current-range"><abbr title="to">–</abbr></span></li><li class="price-save "></li></ul><p class="item-msg"><a href="https://kb.newegg.com/knowledge-base/shipped-by-newegg/" class="shipped-by-newegg">Shipped by Newegg</a></p><div class="item-operate"><div class="item-button-area"><button class="btn btn-primary btn-mini" title="Add PlayStation Store $10 Gift Card (Email Delivery) to cart">Add to cart <i class="fas fa-caret-right"></i></button></div><div class="item-compare-box"><label class="form-checkbox"><input type="checkbox" autoComplete="off"/><span class="form-checkbox-title">Compare</span></label></div></div></div><div class="item-stock" id="stock_32-886-001"></div></div></div><div class="item-cell" id="item_cell_9SIAWVGK2D5003_7_1"><noscript><p>Starts introducing a sponsored item.</p></noscript><div id="9SIAWVGK2D5003" class="item-container"><a href="https://www.newegg.com/p/N82E16868110325?Item=9SIAWVGK2D5003&amp;cm_sp=SP-_-2225290-_-0-_-2-_-9SIAWVGK2D5003-_-playstation-_-playstation-_-9" class="item-img" rel="nofollow"><img s ...
# 1. Sign into PSN or create an account at playstation.com.
# 2. Go to ‘Redeem Codes’ on PS Store and enter the 12-digit voucher code (Code).
# 3. To purchase PS Plus using the funds from this Code, select the subscription plan of your choice, and complete the Purchase*.
# *Credit/debit card may be required to purchase PS Plus 1 month subscription.</li><li><strong>Model #: </strong>SPS-2500</li><li><strong>Item #: </strong>N82E16832886056</li><li><strong>Return Policy: </strong><a href="https://kb.newegg.com/Article/Index/12/3?id=1167#95" target="_blank" title="Digital Products Return Policy(New Window)">Digital Products Return Policy</a></li></ul></div><div class="item-action"><ul class="price"><li class="price-was"></li><li class="price-map"> </li><li class="price-current"><span class="price-current-label"></span>$<strong>25</strong><sup>.00</sup> <span class="price-current-range"><abbr title="to">–</abbr></span></li><li class="price-save "></li></ul><p class="item-msg"><a href="https://kb.newegg.com/knowledge-base/shipped-by-newegg/" class="shipped-by-newegg">Shipped by Newegg</a></p><div class="item-operate"><div class="item-button-area"><button class="btn btn-primary btn-mini" title="Add PlayStation Store $25 Gift Card (Email Delivery) to cart">Add to cart <i class="fas fa-caret-right"></i></button></div><div class="item-compare-box"><label class="form-checkbox"><input type="checkbox" autoComplete="off"/><span class="form-checkbox-title">Compare</span></label></div></div></div><div class="item-stock" id="stock_32-886-056"></div></div></div><div class="item-cell" id="item_cell_9SIBDYFK4G0592_12_1"><noscript><p>Starts introducing a sponsored item.</p></noscript><div id="9SIBDYFK4G0592" class="item-container"><a href="https://www.newegg.com/p/2SW-006Y-00096?Item=9SIBDYFK4G0592&amp;cm_sp=SP-_-2025897-_-0-_-1-_-9SIBDYFK4G0592-_-playstation-_-playstation-_-14" class="item-img" rel="nofollow"><img src="https://c1.neweggimages.com/ProductImageCompressAll300/BDYFS2401040DTSND5F.jpg" title="NEOSMAY Fanless Mini PC Intel 12th Gen Celeron N100(Upto3.4GHz),32GB DDR4 RAM 512GB NVME SSD,Mini Desktop Computer,2 x1000mbps RJ45 LAN,Home/Office/Business,4K Triple Display,WiFi 6,BT 5.2,USB 3.2×4" alt="NEOSMAY Fanless Mini PC Intel 12th Gen Celeron N100(Upto3.4GHz),32GB DDR4 RAM 512GB NVME SSD,Mini Desktop Computer,2 x1000mbps RJ45 LAN,Home/Office/Business,4K Triple Display,WiFi 6,BT 5.2,USB 3.2×4"/><div class="btn btn-large btn-quickview">Quick View</div><div class="item-quick-action-container"><button class="quick-action"><i class="fa fa-heart-outline"></i></button></div></a><div class="item-negspa-box"><div class="menu-box item-negspa"><span><i class="fas fa-info-circle-light"></i> Sponsored</span><div class="menu-box-menu" style="display:none"><div class="menu-box-menu-arrow"></div><div class="article"><p>You’re seeing this ad based on the product’s relevance to your search query. If you are a seller and want to participate in this program click here to <a href='https://www.newegg.com/sellers/index.php/marketing-sponsored-product-ads/' class='link-blue'>learn more</a>.</p></div></div></div></div><div class="item-info"><div class="item-branding has-brand-store"></div><a href="https://www.newegg.com/p/2SW-006Y-00096?Item=9SIBDYFK4G0592&amp;cm_sp=SP-_-2025897-_-0-_-1-_-9SIBDYFK4G0592-_-playstation-_-playstation-_-14" class="item-title" title="View Details" rel="nofollow"><span class="item-open-box-italic"></span>NEOSMAY Fanless Mini PC Intel 12th Gen Celeron N100(Upto3.4GHz),32GB DDR4 RAM 512GB NVME SSD,Mini Desktop Computer,2 x1000mbps RJ45 LAN,Home/Office/Business,4K Triple Display,WiFi 6,BT 5.2,USB 3.2×4</a><ul class="item-features"><li><strong>CPU Type:</strong> Intel 12th Gen Celeron N100</li><li><strong>Memory installed:</strong> 32GB</li><li><strong>Memory slot:</strong> 1 x 260Pin SO-DIMM</li><li><strong>Memory Type Supported:</strong> DDR4 3200</li><li><strong>Model #: </strong>MPN10032512</li><li><strong>Item #: </strong>9SIBDYFK4G0592</li><li><strong>Return Policy: </strong><a href="https://www.newegg.com/Seller-Store/Newsmay-mini-PC?initialTab=returnPolicy" target="_blank" title="View Return Policy(new window)">View Return Policy</a></li></ul></div><div class="item-action"><ul class="price"><li cla ...
# Your use of this PlayStationStore card ("Card") constitutes your acceptance of these terms and any additional terms available at playstationnetwork.com/ terms-of-service. Activated Cards can only be redeemed through an SEN master account subject to prior acceptance of the SEN Terms of Service and User Agreement and applicable Privacy Policy available at playstationnetwork.caREDEMPTION INSTRUCTIONS:
# 1. Sign into PSN or create an account at playstation.com.
# 2. Go to ‘Redeem Codes’ on PS Store and enter the 12-digit voucher code (Code).
# 3. To purchase PS Plus using the funds from this Code, select the subscription plan of your choice, and complete the Purchase*.
# ...
# Starts introducing a sponsored item.Quick View SponsoredYou’re seeing this ad based on the product’s relevance to your search query. If you are a seller and want to participate in this program click here to learn more.(9)PlayStation 5 Console – God of War™ Ragnarök BundleEdition: Standard EditionBundled Game: God of War: RagnarokProcessor Type: AMD Zen 2-based CPU with 8 cores at 3.5GHzInstalled RAM: 16GB GDDR6Model #: 1000032624Item #: 9SIAWVGJPC6112Return Policy: View Return Policy $649.94 –Free Shipping LittleOX StoreVisit Store Top Rated SellerAdd to cart CompareThe introduction for sponsored item ends.
# Quick View(162)PlayStation Store $25 Gift Card (Email Delivery)Disclaimer: N82E16832886056Specifications: REDEMPTION INSTRUCTIONS:
# 1. Sign into PSN or create an account at playstation.com.
# 2. Go to ‘Redeem Codes’ on PS Store and enter the 12-digit voucher code (Code).
# 3. To purchase PS Plus using the funds from this Code, select the subscription plan of your choice, and complete the Purchase*.
# *Credit/debit card may be required to purchase PS Plus 1 month subscription.Model #: SPS-2500Item #: N82E16832886056Return Policy: Digital Products Return Policy $25.00 –Shipped by NeweggAdd to cart Compare
# Starts introducing a sponsored item.Quick View SponsoredYou’re seeing this ad based on the product’s relevance to your search query. If you are a seller and want to participate in this program click here to learn more.NEOSMAY Fanless Mini PC Intel 12th Gen Celeron N100(Upto3.4GHz),32GB DDR4 RAM 512GB NVME SSD,Mini Desktop Computer,2 x1000mbps RJ45 LAN,Home/Office/Business,4K Triple Display,WiFi 6,BT 5.2,USB 3.2×4CPU Type: Intel 12th Gen Celeron N100Memory installed: 32GBMemory slot: 1 x 260Pin SO-DIMMMemory Type Supported: DDR4 3200Model #: MPN10032512Item #: 9SIBDYFK4G0592Return Policy: View Return Policy$399.00 $289.00 –Save: 27%Free ShippingShipped by Newegg Direct from NEOSMAYThis product is sold direct from the manufacturer.Newsmay mini PC StoreVisit StoreAdd to cart CompareThe introduction for sponsored item ends.
# Quick View(55)PS5 Bundle - Includes PS5 Console and an Additional DualSense 5 ControllerEdition: Standard EditionProcessor Type: AMD Zen 2-based CPU with 8 cores at 3.5GHzInstalled RAM: 16GB GDDR6Storage Capacity: Custom 825GB SSDModel #: 875873001825Return Policy: View Return Policy$649.90 $648.95 (3 Offers)–Free Shipping InBulk Electronics StoreVisit Store Top Rated SellerView Details Compare
# Quick View(27)PlayStation 5 Digital Console– God of War™ Ragnarök BundleEdition: Digital EditionBundled Game: God of War: RagnarokProcessor Type: AMD Zen 2-based CPU with 8 cores at 3.5GHzInstalled RAM: 16GB GDDR6Model #: 1000032639Return Policy: View Return Policy $599.99 (2 Offers)–Free Shipping LittleOX StoreVisit Store Top Rated SellerView Details Compare
# Starts introducing a sponsored item.Quick View SponsoredYou’re seeing this ad based on the product’s relevance to your search query. If you are a seller and want to participate in this program click here to learn more.NEOSMAY Fanless Mini PC Intel 12th Gen Celeron N100 max 3.4GHz,16GB DDR4 RAM 512GB NVME SSD,2 x1000mbps RJ45 LAN,Fanless,WiFi ax,BT5.2,DP+HD+COM/VGA display,4xUSB3.0,UHD GraphicsCPU Type: Intel 12th Gen Celeron N100Memory installed: 16GBMemory slot: 1 x 260Pin SO-DIMMMemory Type Supported: DDR4 3200Model #: MINI-N10016512Item #: 9SIBDYFJZP9031Return Policy: View Return Policy$325.00 $249.00 –Save: 23%Free ShippingShipped by Newegg Direct from NEOSMAYThis product is sold direct from the manufacturer.Newsmay mini PC StoreVisit StoreAdd to cart CompareThe introduction for sponsored item ends.
# Quick View(43)PS5 Bundle - Includes Playstation 5 Digital Console, Additional DualSense Controller and HD Camera for PS5Edition: Digital EditionProcessor Type: AMD Zen 2-based CPU with 8 cores at 3.5GHzInstalled RAM: 16GB GDDR6Storage Capacity: Custom 825GB SSDModel #: 875873000194Item #: 9SIA378E0N6850Return Policy: View Return Policy $779.95 –Free Shipping InBulk Electronics StoreVisit Store Top Rated SellerAdd to cart Compare
# Quick View(40)PlayStation 5 Console - Horizon Forbidden West BundleEdition: Standard EditionBundled Game: Horizon Forbidden WestProcessor Type: AMD Zen 2-based CPU with 8 cores at 3.5GHzInstalled RAM: 16GB GDDR6Model #: 1000032000Return Policy: View Return Policy $629.99 (2 Offers)–Free Shipping LittleOX StoreVisit Store Top Rated SellerView Details Compare
# Quick ViewPlayStation Store (Plus Brand) $30 Gift Card (Email Delivery)Disclaimer: Redeemable only by users aged 18 or older holding an adult account for PSN registered to the U.S. PSN wallet funds can be used by the redeeming account holder (and their child Family Member accounts) to pay for items in the PS Store available to U.S. account holders. Use of Code is subject to these terms, and Terms of Service and User Agreement and applicable Privacy Policy at www.playstation.com/legal/PSNTerms. Terms of this Code may change without notice. Void where prohibited or restricted by law. If you do not accept these terms, do not purchase. Subject to applicable local laws, Code is not redeemable for cash, cannot be returned for cash or credit, and may not be resold, exchanged, or used for any other purpose. Code will not be replaced if lost, destroyed, stolen, or otherwise used without your permission. Valid for one time use only. Compatible system a...Model #: PS3000Item #: N82E16832886087Return Policy: Digital Products Return Policy $30.00 –Shipped by NeweggAdd to cart Compare
# Quick ViewLowest pricein 30 days(102)SONY PLAYSTATION 5 DIGITAL EDITION CONSOLEEdition: PS5 DigitalStorage Capacity: 825 GBModel #: PS5 DigitalReturn Policy: View Return Policy $499.99 (2 Offers)–Special ShippingPro-Distributing StoreVisit StoreView Details Compare
# Quick ViewPlayStation 5 Slim Disc consolePart Number: 1000039671Edition: Standard EditionProcessor Type: AMD Zen 2-based CPU with 8 cores at 3.5GHzStorage Capacity: 1TB of SSD storage built inModel #: 1000039671Item #: 9SIA1CZK819872Return Policy: View Return Policy $569.99 –Free Shipping Electronic Express StoreVisit Store Top Rated SellerAdd to cart Compare
# Quick ViewPlayStation Store (Plus Brand) $70 Card (Email Delivery)Disclaimer: Redeemable only by users aged 18 or older holding an adult account for PSN registered to the U.S. PSN wallet funds can be used by the redeeming account holder (and their child Family Member accounts) to pay for items in the PS Store available to U.S. account holders. Use of Code is subject to these terms, and Terms of Service and User Agreement and applicable Privacy Policy at www.playstation.com/legal/PSNTerms. Terms of this Code may change without notice. Void where prohibited or restricted by law. If you do not accept these terms, do not purchase. Subject to applicable local laws, Code is not redeemable for cash, cannot be returned for cash or credit, and may not be resold, exchanged, or used for any other purpose. Code will not be replaced if lost, destroyed, stolen, or otherwise used without your permission. Valid for one time use only. Compatible system a...Model #: PS7000Item #: N82E16832886081Return Policy: Digital Products Return Policy $70.00 –Shipped by NeweggAdd to cart Compare
# Quick ViewPlayStation Store $100 Gift Card (For B2B)Genre: OtherDRM: PlayStationModel #: PSB2B-10000Item #: N82E16832886075Return Policy: Digital Products Return Policy $100.00 –Shipped by NeweggAdd to cart Compare
# Quick View(162)PlayStation Store $75 Gift Card (Email Delivery)Disclaimer: Terms and Conditions
# Your use of this PlayStationStore card ("Card") constitutes your acceptance of these terms and any additional terms available at playstationnetwork.com/ terms-of-service. Activated Cards can only be redeemed through an SEN master account subject to prior acceptance of the SEN Terms of Service and User Agreement and applicable Privacy Policy available at playstationnetwork.caREDEMPTION INSTRUCTIONS:
# 1. Sign into PSN or create an account at playstation.com.
# 2. Go to ‘Redeem Codes’ on PS Store and enter the 12-digit voucher code (Code).
# 3. To purchase PS Plus using the funds from this Code, select the subscription plan of your choice, and complete the Purchase*.
# *Credit/debit card may be required to purchase PS Plus 1 month subscription.om/terms-of-service. PS4, PS3, PS Vita and PSP systems, personal computers, access to the internet, com...Model #: PS7500Item #: N82E16832886062Return Policy: Digital Products Return Policy $75.00 –Shipped by NeweggAdd to cart Compare
# Quick ViewPlayStation Store (Plus Brand) $110 Gift Card (Email Delivery)Disclaimer: Redeemable only by users aged 18 or older holding an adult account for PSN registered to the U.S. PSN wallet funds can be used by the redeeming account holder (and their child Family Member accounts) to pay for items in the PS Store available to U.S. account holders. Use of Code is subject to these terms, and Terms of Service and User Agreement and applicable Privacy Policy at www.playstation.com/legal/PSNTerms. Terms of this Code may change without notice. Void where prohibited or restricted by law. If you do not accept these terms, do not purchase. Subject to applicable local laws, Code is not redeemable for cash, cannot be returned for cash or credit, and may not be resold, exchanged, or used for any other purpose. Code will not be replaced if lost, destroyed, stolen, or otherwise used without your permission. Valid for one time use only. Compatible system a...Model #: PS11000Item #: N82E16832886082Return Policy: Digital Products Return Policy $110.00 –Shipped by NeweggAdd to cart Compare
# Quick View(6)PS5 Bundle - Includes PlayStation 5 Console and an Additional Cosmic Red DualSense ControllerEdition: Standard EditionProcessor Type: AMD Zen 2-based CPU with 8 cores at 3.5GHzInstalled RAM: 16GB GDDR6Storage Capacity: Custom 825GB SSDModel #: 5035CONMIDRDC00Return Policy: View Return Policy $669.95 (2 Offers)–Free Shipping InBulk Electronics StoreVisit Store Top Rated SellerView Details Compare
# Quick View(51)PlayStation 5 Disc Bundle + DualSense Wireless Controller + SpiderMan: Miles MoralesModel #: 3005718-01Return Policy: View Return Policy $699.95 (2 Offers)–Free Shipping InBulk Electronics StoreVisit Store Top Rated SellerView Details Compare
# Quick View(9)PlayStation 5 Console – God of War™ Ragnarök BundleEdition: Standard EditionBundled Game: God of War: RagnarokProcessor Type: AMD Zen 2-based CPU with 8 cores at 3.5GHzInstalled RAM: 16GB GDDR6Model #: 1000032624Item #: 9SIAWVGJPC6112Return Policy: View Return Policy $649.94 –Free Shipping LittleOX StoreVisit Store Top Rated SellerAdd to cart Compare
# Quick ViewMulti-Function Charging Stand with Cooling Fan for PS5 Disc/Digital Edition/PS5 Controller, Vertical Charger Cooling Storage Stand for PS5 VR Playstation (Black)Model #: B091PRCP97Item #: 9SIBJA0JJM0425Return Policy: View Return Policy $39.99 –Free Shipping Direct from GAMFAMIThis product is sold direct from the manufacturer.GAMFAMI StoreVisit StoreAdd to cart Compare
# Quick View(4)PlayStation 5 Disc Console  God of War Ragnarok Bundle with Extra Controller, CefesfyEdition: Standard EditionProcessor Type: AMD Zen 2-based CPU with 8 cores at 3.5GHzInstalled RAM: 16GB GDDR6Storage Capacity: Custom 825GB SSDModel #: GOW-DiscItem #: 9SIAN2HJPM2005Return Policy: View Return Policy $629.00 –Free Shipping Ozeal Electronics StoreVisit Store Top Rated SellerAdd to cart Compare
# Quick ViewSony Playstation 5 Disc Version with Extra DualSense Controller BundleOption: Galactic PurpleModel #: 3005718-3006396Return Policy: View Return Policy $669.95 (2 Offers)–Free Shipping InBulk Electronics StoreVisit Store Top Rated SellerView Details Compare
# Quick ViewPlayStation Store $50 Gift Card (For B2B)Genre: OtherDRM: PlayStationModel #: PSB2B-5000Item #: N82E16832886072Return Policy: Digital Products Return Policy $50.00 –Shipped by NeweggAdd to cart Compare
# Quick ViewPS5 PS4 Camera Adapter Cable, Play PS VR on PS5 Playstation 5, Converter Connecting Cable for PS4 PSVR to PS5 ConsoleLimited time offer, ends 01/22Model #: PAC001Item #: 9SIAMZWHZA8081Return Policy: View Return Policy$21.99 $18.99 –Save: 13%Free Shipping Direct from TROPROThis product is sold direct from the manufacturer.TROPRO StoreVisit StoreAdd to cart Compare
# Quick View(8)PlayStation®5 Digital Edition – Horizon Forbidden West™ BundleModel #: 1000032006Item #: 9SIA6V6J0J3265Return Policy: View Return Policy $609.99 –Free Shipping GeekShopping StoreVisit Store Top Rated SellerAdd to cart Compare
# Quick ViewPlayStation Store $25 Gift Card (For B2B)Genre: OtherDRM: PlayStationModel #: PSB2B-2500Item #: N82E16832886071Return Policy: Digital Products Return Policy $25.00 –Shipped by NeweggAdd to cart Compare
# Quick ViewPlayStation Store (Plus Brand) $55 Gift Card (Email Delivery)Disclaimer: Redeemable only by users aged 18 or older holding an adult account for PSN registered to the U.S. PSN wallet funds can be used by the redeeming account holder (and their child Family Member accounts) to pay for items in the PS Store available to U.S. account holders. Use of Code is subject to these terms, and Terms of Service and User Agreement and applicable Privacy Policy at www.playstation.com/legal/PSNTerms. Terms of this Code may change without notice. Void where prohibited or restricted by law. If you do not accept these terms, do not purchase. Subject to applicable local laws, Code is not redeemable for cash, cannot be returned for cash or credit, and may not be resold, exchanged, or used for any other purpose. Code will not be replaced if lost, destroyed, stolen, or otherwise used without your permission. Valid for one time use only. Compatible system a...Model #: PS5500Item #: N82E16832886080Return Policy: Digital Products Return Policy $55.00 –Shipped by NeweggAdd to cart Compare
# Quick ViewNew PlayStation 5 Console - Call of Duty Modern Warfare II BundleModel #: 1000033303Item #: 9SIAN2HJPC9178Return Policy: View Return Policy $660.00 –Free Shipping Ozeal Electronics StoreVisit Store Top Rated SellerAdd to cart Compare
# Quick ViewPS5 Bundle- Includes PlayStation 5 Digital Console, Additional DualSense Controller, PlayStation Media Remote, and DualSense Charging stationEdition: Digital EditionProcessor Type: AMD Zen 2-based CPU with 8 cores at 3.5GHzInstalled RAM: 16GB GDDR6Storage Capacity: Custom 825GB SSDModel #: 5035DIGICONAC03Item #: 9SIA378HXN4136Return Policy: View Return Policy $729.95 –Free Shipping InBulk Electronics StoreVisit Store Top Rated SellerAdd to cart Compare
# Quick ViewPlayStation 5 Disc Edition Call of Duty Modern Warfare II Bundle with Elden Ring and Mytrix Controller CaseModel #: 850001886123Item #: 9SIA6V6JBA4844Return Policy: View Return Policy $729.99 –Free Shipping GeekShopping StoreVisit Store Top Rated SellerAdd to cart Compare
# Quick View(1)PlayStation®5 Console – FINAL FANTASY XVI BundlePart Number: 1000037776Edition: Standard EditionBundled Game: FINAL FANTASY XVIBackward compatibility: PS4Model #: 1000037776Item #: 9SIAWVGK2E5556Return Policy: View Return Policy $699.99 –Free Shipping LittleOX StoreVisit Store Top Rated SellerAdd to cart Compare
# Quick View#1 Best Sellerin PS5 Systems(7)PlayStation 5 Slim Console – Marvel’s Spider-Man 2 BundleOUT OF STOCKPart Number: 1000037795Edition: Slim ConsoleBundled Game: Marvel’s Spider-Man 2Processor Type: x86-64-AMD Ryzen™ “Zen 2”
# 8 Cores / 16 Threads
# Variable frequency, up to 3.5 GHzModel #: 1000039815Item #: N82E16868110338Return Policy: Manufacturer Only Return Policy$559.99 $499.99 –Save: 10%$11.05 ShippingShipped by NeweggAuto Notify Compare
